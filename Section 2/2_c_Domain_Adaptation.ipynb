# %% [markdown]
# <center><h1>Domain Adaptation</h1></center>
#
# <center><h2><a href="https://arthurdouillard.com/deepcourse/">Course link</a></h2></center>
#
# To keep your modifications in case you want to come back later to this colab, do *File -> Save a copy in Drive*.

# %% [markdown]
# We will implement the paper **Unsupervised Domain Adaptation by Backpropagation** in this session. We strongly advise to read this paper, it's a major one!
#
# https://arxiv.org/abs/1409.7495

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import pickle
import math

import numpy as np
import torch
from torch import nn
from torch.nn import functional as F
from torch.utils.data import DataLoader
from torchvision.datasets import ImageFolder
from torchvision import transforms
import torchvision
from PIL import Image

# %% [markdown]
# We are going to do a **domain adaptation** from a source dataset (MNIST) towards a target dataset (MNIST-M).
#
# First, we need to create the target dataset:

# %%
# !wget https://raw.githubusercontent.com/rdfia/rdfia.github.io/master/code/3-c/mnistm.py
# Out:
# --2024-12-08 22:11:01--  https://raw.githubusercontent.com/rdfia/rdfia.github.io/master/code/3-c/mnistm.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.110.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2918 (2.8K) [text/plain]
# Saving to: ‘mnistm.py.5’
#
# mnistm.py.5         100%[===================>]   2.85K  --.-KB/s    in 0s
#
# 2024-12-08 22:11:01 (38.8 MB/s) - ‘mnistm.py.5’ saved [2918/2918]

# %%
from mnistm import create_mnistm
create_mnistm()

# %% [markdown]
# Then, let's load the MNIST dataset and compute its (train!) mean and standard deviation.
#
# We will use those values to **standardize** both MNIST and MNIST-M.

# %%
mnist_pixels = torchvision.datasets.MNIST('.', train=True, download=True).data / 255
mean = mnist_pixels.mean().item()
std = mnist_pixels.std().item()

print(f"Mean {mean} and Std {std}")

# we will have 3 channels later
mean = torch.tensor([mean, mean, mean])
std = torch.tensor([std, std, std])
# Out:
# Mean 0.13066047430038452 and Std 0.30810782313346863

# %% [markdown]
# Create the loaders for MNIST...

# %%
transform = transforms.Compose([
  transforms.ToTensor(),
  # transform data to 3 channels
  lambda x: x.repeat(3, 1, 1) if x.shape[0] == 1 else x,
  transforms.Normalize(mean, std)
])

mnist_train = torchvision.datasets.MNIST('.', train=True, transform=transform)
mnist_test = torchvision.datasets.MNIST('.', train=False, transform=transform)

source_train_loader = DataLoader(mnist_train, batch_size=128)
source_test_loader = DataLoader(mnist_test, batch_size=128)

# %% [markdown]
# ... and visualize!

# %%
plt.figure(figsize=(10, 7))

for i in range(5):
  ax = plt.subplot(1, 5, i + 1)
  ax.axis('off')

  x, y = mnist_train[i]
  # Transform the data to grayscale format
  # and change the dimension order to (Height, Width, Channels)
  img = ((x * std[:, None, None] + mean[:, None, None]) * 255).permute(1, 2, 0)
  plt.imshow(img.numpy().astype(np.uint8), cmap='gray')
  plt.title(y)

# %% [markdown]
# Likewise, for MNIST-M. We create a simple `Dataset` in order to load the dataset that was serialized as a pickle:

# %%
with open('mnistm_data.pkl', 'rb') as f:
  mnist_m = pickle.load(f) # a dictionary

class MNISTM(torch.utils.data.Dataset):
  def __init__(self, x, y, transform):
    self.x, self.y = x, y
    self.transform = transform

  def __len__(self):
    return len(self.x)

  def __getitem__(self, index):
    x, y = self.x[index], self.y[index]
    x = self.transform(x)

    return x, y

mnistm_train = MNISTM(mnist_m["x_train"], mnist_m["y_train"], transform)
mnistm_test = MNISTM(mnist_m["x_test"], mnist_m["y_test"], transform)

target_train_loader = DataLoader(mnistm_train, batch_size=128)
target_test_loader = DataLoader(mnistm_test, batch_size=128)

# %% [markdown]
# And we also visualize it. Remember to always visualize your data before training a model on it. You may realize that the dataset is ill-formated, in its pixels or targets, and have to do more data preparation beforehand.
#
# Noice that **MNIST-M** is extremely similar to MNIST. The only difference is that the former has colors and textures, and is thus a RGB image. Because MNIST is in grayscale, we have duplicated thrice its channels axis.

# %%
plt.figure(figsize=(10, 7))

for i in range(5):
  ax = plt.subplot(1, 5, i + 1)
  ax.axis('off')

  x, y = mnistm_train[i]
  img = ((x * std[:, None, None] + mean[:, None, None]) * 255).permute(1, 2, 0)
  plt.imshow(img.numpy().astype(np.uint8))
  plt.title(y)

# %% [markdown]
# Now, let's implement this basic network, whose figure is extracted from the paper. Conceive your model so that convolutions do not reduce the spatial dimensions:

# %% [markdown]
# ![cnn_archi_nogrl.png](data:image/png;base64,...)

# %%
class NaiveNet(nn.Module):
  def __init__(self):
    super().__init__()  # Important, otherwise will throw an error


    self.cnn = nn.Sequential(
      # Input size (3,28,28) -conv1-> (32,24,24) -pool1-> (32,12,12)
      nn.Conv2d(in_channels=3, out_channels=32, kernel_size=5, stride=1,padding=0),
      nn.ReLU(),
      nn.MaxPool2d(kernel_size=2,stride=2),

      # (32,12,12) -conv2-> (48,8,8) -pool2-> (48,4,4)
      nn.Conv2d(in_channels=32,out_channels=48, kernel_size=5, stride=1,padding=0),
      nn.ReLU(),
      nn.MaxPool2d(kernel_size=2,stride=2)

    )

    self.classif = nn.Sequential(
      # (48,4,4) -Flatten-> (48,4,4) -fc1-> (100) -fc2-> (100) -fc3-> (10)
      nn.Flatten(),
      nn.Linear(48*4*4,100),
      nn.ReLU(),
      nn.Linear(100,100),
      nn.ReLU(),
      nn.Linear(100,10)
      # No need to add a Softmax layer when we use F.cross_entropy
    )

  def forward(self, x):
    x = self.cnn(x)
    x = self.classif(x)
    return x


NaiveNet()(torch.randn(2, 3, 28, 28)).shape # should be (2,10)
# Out:
# torch.Size([2, 10])

# %%
def eval_model(net, loader):
  net.eval()

  acc, loss = 0, 0.
  c = 0
  for x, y in loader:
    c += len(x)

    with torch.no_grad():
      logits = net(x.cuda()).cpu()

    loss += F.cross_entropy(logits, y).item()
    acc += (logits.argmax(dim=1) == y).sum().item()

  return round(100 * acc / c, 2), round(loss / len(loader), 5)

# %% [markdown]
# Let's train our naive model, but only the source (MNIST) dataset. We will evaluate its performance on the target (MNIST-M) dataset afterwards.
#
# Notice that we use a **learning rate scheduler**. We are updating the learning rate after each epoch according to a function defined with a *lambda* following the paper specification.
#
# We set the initial learning rate to 1.0 because `LambdaLR` defines a *multiplicative factor* of the base learning rate.
#
# It's often useful to reduce likewise the learning rate during training, to facilitate convergence once the model has found a good local minima (we rarely find the global).

# %%
epochs = 10

naive_net = NaiveNet().cuda()

optimizer = torch.optim.SGD(naive_net.parameters(), lr=1.0, momentum=0.9)

mu0, alpha, beta = 0.01, 10, 0.75
scheduler = torch.optim.lr_scheduler.LambdaLR(
    optimizer,
    lambda e: 0.01 / (1 + alpha * e / epochs) ** beta
)

for epoch in range(epochs):
  train_loss = 0.

  for x, y in source_train_loader:
    x, y = x.cuda(), y.cuda()

    optimizer.zero_grad()
    logits = naive_net(x)
    loss = F.cross_entropy(logits, y)
    loss.backward()
    optimizer.step()

    train_loss += loss.item()
  print(f'Epoch {epoch}, train loss: {round(train_loss / len(source_train_loader), 5)}')
  scheduler.step()
  print(f"\tLearning rate = {optimizer.param_groups[0]['lr']}")

test_acc, test_loss = eval_model(naive_net, source_test_loader)
print(f"Test loss: {test_loss}, test acc: {test_acc}")
# Out:
# Epoch 0, train loss: 0.41305
# 	Learning rate = 0.005946035575013606
# Epoch 1, train loss: 0.06397
# 	Learning rate = 0.004386913376508308
# Epoch 2, train loss: 0.04451
# 	Learning rate = 0.0035355339059327372
# Epoch 3, train loss: 0.0359
# 	Learning rate = 0.002990697562442441
# Epoch 4, train loss: 0.03063
# 	Learning rate = 0.0026084743001221454
# Epoch 5, train loss: 0.0269
# 	Learning rate = 0.002323680802425408
# Epoch 6, train loss: 0.02416
# 	Learning rate = 0.0021022410381342864
# Epoch 7, train loss: 0.02195
# 	Learning rate = 0.0019245008972987524
# Epoch 8, train loss: 0.02014
# 	Learning rate = 0.0017782794100389228
# Epoch 9, train loss: 0.0186
# 	Learning rate = 0.0016556002607617019
# Test loss: 0.03122, test acc: 98.88

# %% [markdown]
# Performance on less than 10 epochs are great on MNIST, more than 99% accuracy! But this dataset is quite easy.
#
# Now, the real question is: can our model generalize on the slightly different domain of MNIST-M?

# %%
test_acc, test_loss = eval_model(naive_net, target_test_loader)
print(f"Test loss: {test_loss}, test acc: {test_acc}")
# Out:
# Test loss: 1.30015, test acc: 58.38

# %% [markdown]
# No... You should have an accuracy of 53 to 57%, far less than the 99% we had.
#
# We are going to implement **DANN**, the **Domain Adverserial Neural Network**. The key part of this network is its domain prediction branch and its **gradient reversal layer** (GRL).
#
# The GRL will reverse the gradient between the domain classifier (in pink) and the features extractor (in green).
#
# What does it mean intuitively? The gradient of the domain classifier should help to better classify the domain. Therefore if we reverse it before the end of the features extractor, we will force this CNN to do the opposite: to make the features as agnostic as possible from the domain. Which would mean that the features of MNIST and MNIST-M will be similar and only the digit info will be kept.

# %% [markdown]
# ![cnn_archi.png](data:image/png;base64,...)

# %% [markdown]
# To code a custom backward in PyTorch, you need to define a `torch.autograd.Function`.
#
# The forward is easy, we do nothing except storing a factor that we will need in the backward pass.
#
# In the backward pass we need to return as much gradients as there are inputs (here two). Because the factor is not something to be optimized, we return `None`.
#
# Now, given the factor (which is defaulted to -1, aka "reverse"), define the modified gradient:

# %%
class GradientReversal(torch.autograd.Function):
  @staticmethod
  def forward(ctx, x, factor=-1):
    ctx.save_for_backward(torch.tensor(factor))
    return x

  @staticmethod
  def backward(ctx, grad):
    factor, = ctx.saved_tensors
    reversed_grad = grad*factor

    return reversed_grad, None

# %%
x = torch.tensor([42.], requires_grad=True)
y = torch.tensor([1337.], requires_grad=True)
o = x * y
o.backward()
print(x.grad.item())

x = torch.tensor([42.], requires_grad=True)
y = torch.tensor([1337.], requires_grad=True)
o = GradientReversal.apply(x * y, -1)
o.backward()
print(x.grad.item())
# Out:
# 1337.0
# -1337.0

# %% [markdown]
# To use a PyTorch's `Function`, call its apply
#
# Now, code the DANN. You can re-use parts of the code you wrote for the naive model.

# %% [markdown]
# ![cnn_archi.png](data:image/png;base64,...)

# %%
class DANN(nn.Module):
  def __init__(self):
    super().__init__()  # Important, otherwise will throw an error

    self.cnn = nn.Sequential(
      # Input size (3,28,28) -conv1-> (32,24,24) -pool1-> (32,12,12)
      nn.Conv2d(in_channels=3, out_channels=32, kernel_size=5, stride=1,padding=0),
      nn.ReLU(),
      nn.MaxPool2d(kernel_size=2,stride=2),

      # (32,12,12) -conv2-> (48,8,8) -pool2-> (48,4,4)
      nn.Conv2d(in_channels=32,out_channels=48, kernel_size=5, stride=1,padding=0),
      nn.ReLU(),
      nn.MaxPool2d(kernel_size=2,stride=2)

    )

    self.classif = nn.Sequential(
      # (48,4,4) -Flatten-> (48,4,4) -fc1-> (100) -fc2-> (100) -fc3-> (10)
      nn.Flatten(),
      nn.Linear(48*4*4,100),
      nn.ReLU(),
      nn.Linear(100,100),
      nn.ReLU(),
      nn.Linear(100,10)
      # No need to add a Softmax layer when we use F.cross_entropy
    )

    self.domain = nn.Sequential(
      # (48,4,4) -Flatten-> (48,4,4) -fc1-> (100) -fc2-> (1)
      nn.Flatten(),
      nn.Linear(48*4*4,100),
      nn.ReLU(),
      nn.Linear(100,1),
      # No need to add a Sigmoid layer when we use F.binary_cross_entropy_with_logits
    )

  def forward(self, x, factor=1):
    x = self.cnn(x)
    class_pred = self.classif(x)
    x = GradientReversal.apply(x,factor)
    domain_pred = self.domain(x)

    return class_pred, domain_pred

# %%
def eval_dann(net, loader, source=True):
  net.eval()

  c_acc, d_acc, cls_loss, d_loss = 0, 0, 0., 0.
  c = 0
  for x, y in loader:
    x = x.cuda()
    if source:
      d = torch.ones(len(x))
    else:
      d = torch.zeros(len(x))

    c += len(x)

    with torch.no_grad():
      cls_logits, domain_logits = net(x.cuda())
      cls_logits, domain_logits = cls_logits.cpu(), domain_logits.cpu()

    cls_loss += F.cross_entropy(cls_logits, y).item()
    d_loss += F.binary_cross_entropy_with_logits(domain_logits[:, 0], d).item()

    c_acc += (cls_logits.argmax(dim=1) == y).sum().item()
    d_acc += ((torch.sigmoid(domain_logits[:, 0]) > 0.5).float() == d).sum().item()

  return round(100 * c_acc / c, 2), round(100 * d_acc / c, 2), round(cls_loss / len(loader), 5), round(d_loss / len(loader), 5)

# %%
source_train_loader = DataLoader(mnist_train, batch_size=64)
target_train_loader = DataLoader(mnistm_train, batch_size=64)

len(source_train_loader), len(target_train_loader)
# Out:
# (938, 938)

# %% [markdown]
# For the GRL, using directly a factor -1 will results in very bad performance. Therefore we are going to grow the factor gradually during training (deep learning is an art!).
#
# Here is a plot of the function we will use (note that it is a modified version from the paper):

# %%
nb_iters = (len(source_train_loader) * epochs)

x = [i for i in range(nb_iters)]
lmbd = lambda e: -1 + 2 / (1 + math.exp(-2 * e / nb_iters))
y = [lmbd(i) for i in x]

plt.plot(x, y)

# %% [markdown]
# Let's train our DANN. The GRL factor will be updated after each batch.
#
# Remember that we are not allowed to use the labels of MNIST-M as we assume this dataset is **unlabeled**.

# %%
epochs = 20

dann = DANN().cuda()

optimizer = torch.optim.SGD(dann.parameters(), lr=1.0, momentum=0.9)

mu0, alpha, beta = 0.01, 10, 0.75
scheduler = torch.optim.lr_scheduler.LambdaLR(
    optimizer,
    lambda e: 0.01 / (1 + alpha * e / epochs) ** beta
)
lmbd = lambda e: -1 + 2 / (1 + math.exp(-2 * e / (len(source_train_loader) * epochs)))

b = 0
for epoch in range(epochs):
  cls_loss, domain_loss = 0., 0.
  grl_factor = -lmbd(b)  # should be negative
  print(f"GRL factor {grl_factor}" )

  for (xs, ys), (xt, _) in zip(source_train_loader, target_train_loader):
    grl_factor = -lmbd(b) # should be negative
    b += 1

    xs, ys = xs.cuda(), ys.cuda()
    xt = xt.cuda()
    x = torch.cat((xs, xt))

    optimizer.zero_grad()
    cls_logits, domain_logits = dann(x, factor=grl_factor)

    # Label prediction loss
    ce = F.cross_entropy(cls_logits[:len(xs)],ys)

    # Domain classification loss
    domain_labels = torch.cat((torch.zeros(len(xs),1),torch.ones(len(xt),1))).cuda()
    bce = F.binary_cross_entropy_with_logits(domain_logits,domain_labels)

    loss = ce + bce
    loss.backward()
    optimizer.step()

    cls_loss += ce.item()
    domain_loss += bce.item()

  cls_loss = round(cls_loss / len(source_train_loader), 5)
  domain_loss = round(domain_loss / (2 * len(source_train_loader)), 5)
  print(f'Epoch {epoch}, class loss: {cls_loss}, domain loss: {domain_loss}')
  scheduler.step()

c_acc, d_acc, c_loss, d_loss = eval_dann(dann, source_test_loader)
print(f"[SOURCE] Class loss/acc: {c_loss} / {c_acc}%, Domain loss/acc: {d_loss} / {d_acc}%")

c_acc, d_acc, c_loss, d_loss = eval_dann(dann, target_test_loader, source=False)
print(f"[TARGET] Class loss/acc: {c_loss} / {c_acc}%, Domain loss/acc: {d_loss} / {d_acc}%")
# Out:
# GRL factor -0.0
# Epoch 0, class loss: 0.24846, domain loss: 0.11439
# GRL factor -0.049958374957880025
# Epoch 1, class loss: 0.04943, domain loss: 0.10983
# GRL factor -0.0996679946249559
# Epoch 2, class loss: 0.03267, domain loss: 0.11214
# GRL factor -0.14888503362331806
# Epoch 3, class loss: 0.02661, domain loss: 0.11416
# GRL factor -0.197375320224904
# Epoch 4, class loss: 0.02586, domain loss: 0.13329
# GRL factor -0.2449186624037092
# Epoch 5, class loss: 0.03716, domain loss: 0.16387
# GRL factor -0.2913126124515908
# Epoch 6, class loss: 0.04793, domain loss: 0.21798
# GRL factor -0.3363755443363323
# Epoch 7, class loss: 0.07217, domain loss: 0.23976
# GRL factor -0.379948962255225
# Epoch 8, class loss: 0.06158, domain loss: 0.27979
# GRL factor -0.4218990052500078
# Epoch 9, class loss: 0.06683, domain loss: 0.29912
# GRL factor -0.4621171572600098
# Epoch 10, class loss: 0.03987, domain loss: 0.2732
# GRL factor -0.5005202111902354
# Epoch 11, class loss: 0.03547, domain loss: 0.27842
# GRL factor -0.5370495669980351
# Epoch 12, class loss: 0.02902, domain loss: 0.28071
# GRL factor -0.5716699660851172
# Epoch 13, class loss: 0.02738, domain loss: 0.28432
# GRL factor -0.6043677771171634
# Epoch 14, class loss: 0.0256, domain loss: 0.28426
# GRL factor -0.6351489523872873
# Epoch 15, class loss: 0.02495, domain loss: 0.28358
# GRL factor -0.6640367702678489
# Epoch 16, class loss: 0.02582, domain loss: 0.2884
# GRL factor -0.6910694698329305
# Epoch 17, class loss: 0.02571, domain loss: 0.28964
# GRL factor -0.7162978701990246
# Epoch 18, class loss: 0.02598, domain loss: 0.29229
# GRL factor -0.7397830512740042
# Epoch 19, class loss: 0.02738, domain loss: 0.2941
# [SOURCE] Class loss/acc: 0.04002 / 98.69%, Domain loss/acc: 0.92751 / 25.62%
# [TARGET] Class loss/acc: 0.94622 / 76.51%, Domain loss/acc: 1.49236 / 38.32%

# %% [markdown]
# We should see a huge gain, from the ~55% of accuracy on MNIST-M to more than 73% of accuracy without ever seeing labels of MNIST-M.
#
# This is a very nice gain. Let's now verify visualy that our features space is indeed agnostic to the domain:

# %%
def extract_emb(net, loader):
  embeddings = []

  for x, _ in loader:
    with torch.no_grad():
      feats = net.cnn(x.cuda()).view(len(x), -1).cpu()

    embeddings.append(feats.numpy())

  return np.concatenate(embeddings)

# %% [markdown]
# We use **TSNE** to visualize the embeddings. As you can guess, a human cannot comprehend a space of hundred of dimensions, thus TSNE can project this space onto a space of 2 dimensions.
#
# But beware of the several drawbacks of TSNE:
# - **it is super slow**, so we will compute it on a subset of the data
# - **it is not determinist**, so you can have different results everytime
# - **it can be tuned**, and as everything that can be tuned, you can "*force*" it to take some aspect that you wish it has, while not being really representative of the real data
#
# If you want to learn more about TSNE, head off to this fantastic website: https://distill.pub/2016/misread-tsne/

# %%
from sklearn.manifold import TSNE

# %%
source_emb = extract_emb(naive_net, source_train_loader)
target_emb = extract_emb(naive_net, target_train_loader)

print("Original embeddings of source / target", source_emb.shape, target_emb.shape)

indexes = np.random.permutation(len(source_emb))[:1000]

emb = np.concatenate((source_emb[indexes], target_emb[indexes]))
domains = np.concatenate((np.ones((1000,)), np.zeros((1000,))))

print("Samples embeddings", emb.shape, domains.shape)

tsne = TSNE(n_components=2)

emb_2d = tsne.fit_transform(emb)
print("Dimension reduced embeddings", emb_2d.shape)

plt.scatter(emb_2d[:, 0], emb_2d[:, 1], c=domains)
plt.title("Without domain adaptation")
# Out:
# Original embeddings of source / target (60000, 768) (60000, 768)
# Samples embeddings (2000, 768) (2000,)
# Dimension reduced embeddings (2000, 2)
# Text(0.5, 1.0, 'Without domain adaptation')

# %% [markdown]
# Yellow dots are the source (MNIST) dataset, while purple dots are the target dataset (MNIST-M). We can clearly see that they belong to different space if we use the naive model.

# %%
source_emb = extract_emb(dann, source_train_loader)
target_emb = extract_emb(dann, target_train_loader)

print("Original embeddings of source / target", source_emb.shape, target_emb.shape)

indexes = np.random.permutation(len(source_emb))[:1000]

emb = np.concatenate((source_emb[indexes], target_emb[indexes]))
domains = np.concatenate((np.ones((1000,)), np.zeros((1000,))))

print("Samples embeddings", emb.shape, domains.shape)

tsne = TSNE(n_components=2)

emb_2d = tsne.fit_transform(emb)
print("Dimension reduced embeddings", emb_2d.shape)

plt.scatter(emb_2d[:, 0], emb_2d[:, 1], c=domains)
plt.title("With domain adaptation")
# Out:
# Original embeddings of source / target (60000, 768) (60000, 768)
# Samples embeddings (2000, 768) (2000,)
# Dimension reduced embeddings (2000, 2)
# Text(0.5, 1.0, 'With domain adaptation')

# %% [markdown]
# But with our DANN, while still imperfect, the two domains are much more merged. This confirm our intuition that the GRL forces the network to produce domain-agnostic features.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Our model is still lower than the performance reported in the original paper. You can try to further improve it by:
#
# - use much more epochs
# - modify the learning rate scheduler to be updated per step
# - test different standardization
# - different GRL factor scheduling

# %%
epochs = 100
dann2 = DANN().cuda()
optimizer = torch.optim.SGD(dann2.parameters(), lr=1.0, momentum=0.9)
mu0, alpha, beta = 0.01, 10, 0.75

# introduce step decay
step_epochs = [int(epochs * 0.2), int(epochs * 0.5), int(epochs * 0.75)]
def step_decay_scheduler(e):
    base_lr = mu0 / (1 + alpha * e / epochs) ** beta
    if e > step_epochs[2]:
        return base_lr * 0.05   # last stage
    elif e > step_epochs[1]:
        return base_lr * 0.1   # high stage
    elif e > step_epochs[0]:
        return base_lr * 0.5   # medium stage
    else:
        return base_lr

scheduler = torch.optim.lr_scheduler.LambdaLR(optimizer, step_decay_scheduler)
lmbd = lambda e: -1 + 2 / (1 + math.exp(-10 * e / (len(source_train_loader) * epochs)))

target_acc = []
source_acc = []

b = 0
for epoch in range(epochs):
  cls_loss, domain_loss = 0., 0.
  grl_factor = -lmbd(b)  # should be negative
  print(f"GRL factor {grl_factor}" )

  for (xs, ys), (xt, _) in zip(source_train_loader, target_train_loader):
    grl_factor = -lmbd(b) # should be negative
    b += 1

    xs, ys = xs.cuda(), ys.cuda()
    xt = xt.cuda()
    x = torch.cat((xs, xt))

    optimizer.zero_grad()
    cls_logits, domain_logits = dann2(x, factor=grl_factor)

    # Label prediction loss
    ce = F.cross_entropy(cls_logits[:len(xs)],ys)

    # Domain classification loss
    domain_labels = torch.cat((torch.zeros(len(xs),1),torch.ones(len(xt),1))).cuda()
    bce = F.binary_cross_entropy_with_logits(domain_logits,domain_labels)

    loss = ce + bce
    loss.backward()
    optimizer.step()

    cls_loss += ce.item()
    domain_loss += bce.item()

  cls_loss = round(cls_loss / len(source_train_loader), 5)
  domain_loss = round(domain_loss / (2 * len(source_train_loader)), 5)
  print(f'Epoch {epoch}, class loss: {cls_loss}, domain loss: {domain_loss}')
  scheduler.step()

  c_acc, d_acc, c_loss, d_loss = eval_dann(dann2, source_test_loader)
  print(f"[SOURCE] Class loss/acc: {c_loss} / {c_acc}%, Domain loss/acc: {d_loss} / {d_acc}%")
  source_acc.append(c_acc)

  c_acc, d_acc, c_loss, d_loss = eval_dann(dann2, target_test_loader, source=False)
  print(f"[TARGET] Class loss/acc: {c_loss} / {c_acc}%, Domain loss/acc: {d_loss} / {d_acc}%")
  target_acc.append(c_acc)

  dann2.train()
# Out:
# GRL factor -0.0
# Epoch 0, class loss: 0.2335, domain loss: 0.12508
# [SOURCE] Class loss/acc: 0.05747 / 98.19%, Domain loss/acc: 3.99645 / 1.34%
# [TARGET] Class loss/acc: 1.17381 / 61.98%, Domain loss/acc: 3.36318 / 12.58%
# GRL factor -0.049958374957880025
# Epoch 1, class loss: 0.05259, domain loss: 0.09957
# [SOURCE] Class loss/acc: 0.04051 / 98.74%, Domain loss/acc: 3.98119 / 3.42%
# [TARGET] Class loss/acc: 1.14342 / 63.41%, Domain loss/acc: 4.69029 / 14.11%
# GRL factor -0.0996679946249559
# Epoch 2, class loss: 0.03753, domain loss: 0.11363
# [SOURCE] Class loss/acc: 0.03155 / 98.92%, Domain loss/acc: 3.42435 / 3.99%
# [TARGET] Class loss/acc: 1.13164 / 64.49%, Domain loss/acc: 4.06559 / 15.64%
# GRL factor -0.14888503362331806
# Epoch 3, class loss: 0.03389, domain loss: 0.14301
# [SOURCE] Class loss/acc: 0.04994 / 98.38%, Domain loss/acc: 2.52603 / 14.69%
# [TARGET] Class loss/acc: 1.21302 / 64.54%, Domain loss/acc: 3.50152 / 20.71%
# GRL factor -0.197375320224904
# Epoch 4, class loss: 0.04833, domain loss: 0.19109
# [SOURCE] Class loss/acc: 0.08555 / 97.68%, Domain loss/acc: 0.21031 / 90.52%
# [TARGET] Class loss/acc: 2.0071 / 55.31%, Domain loss/acc: 12.05041 / 0.2%
# GRL factor -0.2449186624037092
# Epoch 5, class loss: 0.08569, domain loss: 0.20211
# [SOURCE] Class loss/acc: 0.06945 / 97.69%, Domain loss/acc: 2.09596 / 16.51%
# [TARGET] Class loss/acc: 0.96953 / 69.71%, Domain loss/acc: 2.22976 / 26.58%
# GRL factor -0.2913126124515908
# Epoch 6, class loss: 0.05926, domain loss: 0.26758
# [SOURCE] Class loss/acc: 0.06438 / 97.85%, Domain loss/acc: 0.82065 / 54.54%
# [TARGET] Class loss/acc: 1.03914 / 67.92%, Domain loss/acc: 1.86621 / 23.0%
# GRL factor -0.3363755443363323
# Epoch 7, class loss: 0.05532, domain loss: 0.29422
# [SOURCE] Class loss/acc: 0.0457 / 98.37%, Domain loss/acc: 1.13183 / 18.81%
# [TARGET] Class loss/acc: 1.08648 / 72.85%, Domain loss/acc: 1.81284 / 41.79%
# GRL factor -0.379948962255225
# Epoch 39, class loss: 0.01839, domain loss: 0.324
# [SOURCE] Class loss/acc: 0.04153 / 98.8%, Domain loss/acc: 0.81965 / 26.73%
# [TARGET] Class loss/acc: 1.05714 / 74.64%, Domain loss/acc: 0.94225 / 44.76%
# GRL factor -0.9640275800758169
# Epoch 40, class loss: 0.01809, domain loss: 0.32529
# [SOURCE] Class loss/acc: 0.04814 / 98.55%, Domain loss/acc: 0.81828 / 31.4%
# [TARGET] Class loss/acc: 1.12626 / 73.8%, Domain loss/acc: 0.9284 / 46.4%
# GRL factor -0.9673950012571182
# Epoch 41, class loss: 0.01913, domain loss: 0.32335
# [SOURCE] Class loss/acc: 0.03565 / 98.9%, Domain loss/acc: 0.78365 / 33.7%
# [TARGET] Class loss/acc: 0.91043 / 77.21%, Domain loss/acc: 0.96792 / 36.74%
# GRL factor -0.9704519366134539
# Epoch 42, class loss: 0.01768, domain loss: 0.32357
# [SOURCE] Class loss/acc: 0.05225 / 98.38%, Domain loss/acc: 0.82414 / 29.5%
# [TARGET] Class loss/acc: 0.85385 / 76.92%, Domain loss/acc: 0.87415 / 48.99%
# GRL factor -0.9732261643446702
# Epoch 43, class loss: 0.01512, domain loss: 0.32214
# [SOURCE] Class loss/acc: 0.03655 / 98.97%, Domain loss/acc: 0.78359 / 38.65%
# [TARGET] Class loss/acc: 0.82888 / 78.09%, Domain loss/acc: 1.01583 / 35.49%
# GRL factor -0.9757431300314514
# Epoch 44, class loss: 0.01596, domain loss: 0.32446
# [SOURCE] Class loss/acc: 0.04035 / 98.76%, Domain loss/acc: 0.77385 / 37.85%
# [TARGET] Class loss/acc: 0.86577 / 77.11%, Domain loss/acc: 0.91228 / 40.85%
# GRL factor -0.9780261147388136
# Epoch 45, class loss: 0.01804, domain loss: 0.32417
# [SOURCE] Class loss/acc: 0.0433 / 98.68%, Domain loss/acc: 0.79677 / 30.65%
# [TARGET] Class loss/acc: 0.85025 / 76.75%, Domain loss/acc: 0.88908 / 43.09%
# GRL factor -0.9800963962661915
# Epoch 46, class loss: 0.01581, domain loss: 0.32373
# [SOURCE] Class loss/acc: 0.04128 / 98.77%, Domain loss/acc: 0.73732 / 40.97%
# [TARGET] Class loss/acc: 0.93795 / 75.82%, Domain loss/acc: 1.00352 / 33.08%
# GRL factor -0.9819734026943041
# Epoch 47, class loss: 0.01585, domain loss: 0.32164
# [SOURCE] Class loss/acc: 0.04596 / 98.67%, Domain loss/acc: 0.79398 / 33.42%
# [TARGET] Class loss/acc: 0.93803 / 76.04%, Domain loss/acc: 0.99632 / 38.99%
# GRL factor -0.9836748576936802
# Epoch 48, class loss: 0.02044, domain loss: 0.32451
# [SOURCE] Class loss/acc: 0.05121 / 98.68%, Domain loss/acc: 0.80415 / 30.71%
# [TARGET] Class loss/acc: 0.91831 / 76.39%, Domain loss/acc: 0.90564 / 43.1%
# GRL factor -0.9852169173114362
# Epoch 49, class loss: 0.01424, domain loss: 0.32355
# GRL factor -0.9981778976111988
# Epoch 70, class loss: 0.01202, domain loss: 0.32134
# [SOURCE] Class loss/acc: 0.0433 / 98.84%, Domain loss/acc: 0.80913 / 32.64%
# [TARGET] Class loss/acc: 0.87813 / 77.33%, Domain loss/acc: 0.94091 / 39.65%
# GRL factor -0.9983511506272034
# Epoch 71, class loss: 0.01242, domain loss: 0.32125
# [SOURCE] Class loss/acc: 0.04248 / 98.84%, Domain loss/acc: 0.80496 / 32.74%
# [TARGET] Class loss/acc: 0.90082 / 77.11%, Domain loss/acc: 0.94653 / 38.68%
# GRL factor -0.9985079423323266
# Epoch 72, class loss: 0.01278, domain loss: 0.32083
# [SOURCE] Class loss/acc: 0.04287 / 98.78%, Domain loss/acc: 0.80784 / 34.08%
# [TARGET] Class loss/acc: 0.87369 / 77.69%, Domain loss/acc: 0.9638 / 37.43%
# GRL factor -0.9986498345387345
# Epoch 73, class loss: 0.01224, domain loss: 0.31988
# [SOURCE] Class loss/acc: 0.04394 / 98.76%, Domain loss/acc: 0.82451 / 32.2%
# [TARGET] Class loss/acc: 0.96816 / 76.74%, Domain loss/acc: 0.97599 / 39.45%
# GRL factor -0.9987782412811312
# Epoch 74, class loss: 0.01619, domain loss: 0.32453
# [SOURCE] Class loss/acc: 0.05344 / 98.53%, Domain loss/acc: 0.80086 / 37.57%
# [TARGET] Class loss/acc: 0.92226 / 76.49%, Domain loss/acc: 0.94147 / 37.71%
# GRL factor -0.9988944427261528
# Epoch 75, class loss: 0.02232, domain loss: 0.32759
# [SOURCE] Class loss/acc: 0.04878 / 98.65%, Domain loss/acc: 0.85649 / 28.63%
# [TARGET] Class loss/acc: 0.83516 / 78.06%, Domain loss/acc: 0.84907 / 42.88%
# GRL factor -0.998999597785841
# Epoch 76, class loss: 0.01638, domain loss: 0.32419
# [SOURCE] Class loss/acc: 0.04611 / 98.72%, Domain loss/acc: 0.85012 / 29.17%
# [TARGET] Class loss/acc: 0.8083 / 78.65%, Domain loss/acc: 0.85628 / 42.74%
# GRL factor -0.999094755553519
# Epoch 77, class loss: 0.01381, domain loss: 0.32332
# [SOURCE] Class loss/acc: 0.04541 / 98.81%, Domain loss/acc: 0.8472 / 29.98%
# [TARGET] Class loss/acc: 0.8103 / 78.39%, Domain loss/acc: 0.8783 / 41.54%
# GRL factor -0.9991808656700278
# Epoch 78, class loss: 0.01181, domain loss: 0.31993
# [SOURCE] Class loss/acc: 0.04498 / 98.84%, Domain loss/acc: 0.85134 / 29.13%
# [TARGET] Class loss/acc: 0.82256 / 78.58%, Domain loss/acc: 0.90375 / 40.17%
# GRL factor -0.9992587877187471
# Epoch 79, class loss: 0.01127, domain loss: 0.31839
# [SOURCE] Class loss/acc: 0.04617 / 98.71%, Domain loss/acc: 0.83316 / 31.1%
# [TARGET] Class loss/acc: 0.80585 / 78.88%, Domain loss/acc: 0.92105 / 38.14%
# GRL factor -0.9993292997390673
# Epoch 80, class loss: 0.01282, domain loss: 0.3207
# [SOURCE] Class loss/acc: 0.04834 / 98.59%, Domain loss/acc: 0.81344 / 33.72%
# [TARGET] Class loss/acc: 0.78057 / 79.09%, Domain loss/acc: 0.91692 / 37.52%
# GRL factor -0.9993931059399423
# Epoch 81, class loss: 0.01514, domain loss: 0.32369
# [SOURCE] Class loss/acc: 0.04768 / 98.6%, Domain loss/acc: 0.80415 / 34.43%
# [TARGET] Class loss/acc: 0.78232 / 78.52%, Domain loss/acc: 0.90074 / 38.2%
# GRL factor -0.9994508436877971
# Epoch 82, class loss: 0.01625, domain loss: 0.32643
# [SOURCE] Class loss/acc: 0.04696 / 98.67%, Domain loss/acc: 0.80304 / 34.47%
# [TARGET] Class loss/acc: 0.79144 / 78.17%, Domain loss/acc: 0.89004 / 38.68%
# GRL factor -0.9995030898363211
# Epoch 83, class loss: 0.01536, domain loss: 0.32217
# [SOURCE] Class loss/acc: 0.04437 / 98.76%, Domain loss/acc: 0.81442 / 32.29%
# [TARGET] Class loss/acc: 0.79412 / 78.67%, Domain loss/acc: 0.90748 / 37.03%
# GRL factor -0.9995503664595333
# Epoch 84, class loss: 0.0126, domain loss: 0.32082
# [SOURCE] Class loss/acc: 0.04222 / 98.88%, Domain loss/acc: 0.82378 / 31.85%
# [TARGET] Class loss/acc: 0.78996 / 78.99%, Domain loss/acc: 0.90724 / 38.36%
# GRL factor -0.9995931460438896
# Epoch 85, class loss: 0.01112, domain loss: 0.32046
# [SOURCE] Class loss/acc: 0.04244 / 98.84%, Domain loss/acc: 0.83667 / 30.94%
# [TARGET] Class loss/acc: 0.7906 / 78.7%, Domain loss/acc: 0.91474 / 37.83%
# GRL factor -0.9996318561900732
# Epoch 86, class loss: 0.01032, domain loss: 0.31824
# [SOURCE] Class loss/acc: 0.04276 / 98.89%, Domain loss/acc: 0.83925 / 30.63%
# [TARGET] Class loss/acc: 0.78115 / 79.01%, Domain loss/acc: 0.92926 / 37.58%
# GRL factor -0.9996668838704454
# Epoch 87, class loss: 0.01022, domain loss: 0.31821
# [SOURCE] Class loss/acc: 0.0435 / 98.87%, Domain loss/acc: 0.82487 / 31.76%
# [TARGET] Class loss/acc: 0.76122 / 79.33%, Domain loss/acc: 0.93576 / 37.68%
# GRL factor -0.9996985792838806
# Epoch 88, class loss: 0.01071, domain loss: 0.32095
# [SOURCE] Class loss/acc: 0.04441 / 98.81%, Domain loss/acc: 0.81564 / 32.34%
# [TARGET] Class loss/acc: 0.75553 / 79.25%, Domain loss/acc: 0.93117 / 38.43%
# GRL factor -0.9997272593458408
# Epoch 89, class loss: 0.01117, domain loss: 0.32284
# [SOURCE] Class loss/acc: 0.04463 / 98.81%, Domain loss/acc: 0.80795 / 33.29%
# [TARGET] Class loss/acc: 0.75293 / 79.32%, Domain loss/acc: 0.93199 / 38.65%
# GRL factor -0.9997532108480274
# Epoch 90, class loss: 0.01155, domain loss: 0.32297
# [SOURCE] Class loss/acc: 0.04498 / 98.76%, Domain loss/acc: 0.79804 / 34.14%
# [TARGET] Class loss/acc: 0.74856 / 79.49%, Domain loss/acc: 0.93746 / 37.91%
# GRL factor -0.9997766933187409
# Epoch 91, class loss: 0.01188, domain loss: 0.32202
# [SOURCE] Class loss/acc: 0.04507 / 98.72%, Domain loss/acc: 0.79678 / 34.49%
# [TARGET] Class loss/acc: 0.74924 / 79.63%, Domain loss/acc: 0.94122 / 37.55%
# GRL factor -0.9997979416121845
# Epoch 92, class loss: 0.01223, domain loss: 0.32104
# [SOURCE] Class loss/acc: 0.0445 / 98.73%, Domain loss/acc: 0.79922 / 33.63%
# [TARGET] Class loss/acc: 0.74804 / 79.48%, Domain loss/acc: 0.93855 / 37.82%
# GRL factor -0.9998171682522956
# Epoch 93, class loss: 0.01244, domain loss: 0.32102
# [SOURCE] Class loss/acc: 0.04416 / 98.77%, Domain loss/acc: 0.80038 / 33.52%
# [TARGET] Class loss/acc: 0.74998 / 79.38%, Domain loss/acc: 0.92794 / 38.43%
# GRL factor -0.9998345655542968
# Epoch 94, class loss: 0.01264, domain loss: 0.32171
# [SOURCE] Class loss/acc: 0.04402 / 98.77%, Domain loss/acc: 0.80004 / 33.51%
# [TARGET] Class loss/acc: 0.75711 / 78.94%, Domain loss/acc: 0.91531 / 39.09%
# GRL factor -0.999850307544979
# Epoch 95, class loss: 0.0125, domain loss: 0.32234
# [SOURCE] Class loss/acc: 0.04359 / 98.78%, Domain loss/acc: 0.80072 / 33.45%
# [TARGET] Class loss/acc: 0.76849 / 78.48%, Domain loss/acc: 0.90879 / 39.65%
# GRL factor -0.9998645517007607
# Epoch 96, class loss: 0.01216, domain loss: 0.32261
# [SOURCE] Class loss/acc: 0.04316 / 98.8%, Domain loss/acc: 0.79928 / 33.66%
# [TARGET] Class loss/acc: 0.77139 / 78.47%, Domain loss/acc: 0.90875 / 39.52%
# GRL factor -0.9998774405207667
# Epoch 97, class loss: 0.01206, domain loss: 0.32293
# [SOURCE] Class loss/acc: 0.04316 / 98.78%, Domain loss/acc: 0.79465 / 34.26%
# [TARGET] Class loss/acc: 0.77311 / 78.49%, Domain loss/acc: 0.90811 / 39.51%
# GRL factor -0.9998891029505543
# Epoch 98, class loss: 0.01236, domain loss: 0.32378
# [SOURCE] Class loss/acc: 0.04347 / 98.73%, Domain loss/acc: 0.79181 / 35.06%
# [TARGET] Class loss/acc: 0.78644 / 78.37%, Domain loss/acc: 0.90324 / 39.92%
# GRL factor -0.9998996556706323
# Epoch 99, class loss: 0.01245, domain loss: 0.32391
# [SOURCE] Class loss/acc: 0.04283 / 98.72%, Domain loss/acc: 0.79043 / 35.36%
# [TARGET] Class loss/acc: 0.80292 / 78.39%, Domain loss/acc: 0.90814 / 39.74%

# %%
# Plot the accuracies
plt.figure(figsize=(10, 6))
plt.plot(range(len(source_acc)), source_acc, label='Source Accuracy')
plt.plot(range(len(target_acc)), target_acc, label='Target Accuracy', linestyle='--')
plt.xlabel('Epochs')
plt.ylabel('Accuracy (%)')
plt.title('Source and Target Accuracy Over Training Epochs')
plt.legend()
plt.grid(True)
plt.show()
